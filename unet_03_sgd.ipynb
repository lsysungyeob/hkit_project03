# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import re
from pathlib import Path
import SimpleITK as sitk
import numpy as np
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
def normalize(img):
    max_value = img.max()
    min_value = img.min()
    
    return (img - min_value) / (max_value - min_value + 1e-8)

def image_pad_crop(img, mask, size, margin=1):
    if img.ndim == 3 and img.shape[2] == 1:
        non_black_flat = img[:,:,0] > 0
    elif img.ndim == 2:
        non_black_flat = img > 0
    else:
        non_black_flat = np.sum(img, axis=-1) > 0 if img.ndim == 3 else np.sum(img, axis=0) > 0
        
    coords = np.argwhere(non_black_flat)

    if len(coords) == 0:
        if img.ndim == 3:
            h, w, _ = img.shape
        else:
            h, w = img.shape
        center_y, center_x = h // 2, w // 2
    else:
        y_min, x_min = coords.min(axis=0)
        y_max, x_max = coords.max(axis=0)

        if img.ndim == 3:
            h, w, _ = img.shape
        else:
            h, w = img.shape
            
        y_min = max(0, y_min - margin)
        x_min = max(0, x_min - margin)
        y_max = min(h - 1, y_max + margin)
        x_max = min(w - 1, x_max + margin)
        
        center_y = (y_min + y_max) // 2
        center_x = (x_min + x_max) // 2

    half_size = size // 2
    crop_start_y = center_y - half_size
    crop_end_y = center_y + half_size
    crop_start_x = center_x - half_size
    crop_end_x = center_x + half_size

    if img.ndim == 3: # (H, W, C)
        img_result = np.zeros((size, size, img.shape[2]), dtype=img.dtype)
    else: # (H, W)
        img_result = np.zeros((size, size), dtype=img.dtype)
        
    mask_result = np.zeros((size, size), dtype=mask.dtype)

    src_start_y = max(0, crop_start_y)
    src_end_y = min(h, crop_end_y) 
    src_start_x = max(0, crop_start_x)
    src_end_x = min(w, crop_end_x) 
    
    dest_start_y = max(0, -crop_start_y)
    dest_end_y = dest_start_y + (src_end_y - src_start_y)
    dest_start_x = max(0, -crop_start_x)
    dest_end_x = dest_start_x + (src_end_x - src_start_x)

    img_result[dest_start_y:dest_end_y, dest_start_x:dest_end_x] = img[src_start_y:src_end_y, src_start_x:src_end_x]
    mask_result[dest_start_y:dest_end_y, dest_start_x:dest_end_x] = mask[src_start_y:src_end_y, src_start_x:src_end_x]
    
    return img_result, mask_result

class BraTSDataset(Dataset):
    def __init__(self, data_list, transform=None, out_size=256):
        self.data_list = data_list
        self.transform = transform
        self.out_size = out_size
        
    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        z_current, img_path, mask_path = self.data_list[idx]
        
        full_image_volume = sitk.GetArrayFromImage(sitk.ReadImage(img_path)) 
        full_mask_volume = sitk.GetArrayFromImage(sitk.ReadImage(mask_path)) 

        total_slices = full_image_volume.shape[0]

        z_prev = max(0, z_current - 1)
        z_next = min(total_slices - 1, z_current + 1)

        image_prev = full_image_volume[z_prev]
        image_current = full_image_volume[z_current]
        image_next = full_image_volume[z_next]
        
        mask_data = full_mask_volume[z_current]

        image_prev_norm = normalize(image_prev)
        image_current_norm = normalize(image_current)
        image_next_norm = normalize(image_next)

        combined_image_3channel = np.stack([image_prev_norm, image_current_norm, image_next_norm], axis=-1) # (H, W, 3)

        image_new, mask_new = image_pad_crop(combined_image_3channel, mask_data, self.out_size)
        
        make_t = self.transform(image=image_new, mask=mask_new)
        image_tensor = make_t['image'] 
        mask_tensor = make_t['mask']
        
        return image_tensor.float(), mask_tensor.float().unsqueeze(0)

# %%
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=10, p=0.7),
    A.ShiftScaleRotate(shift_limit=0.02, scale_limit=0.05, rotate_limit=0, p=0.7),
    A.ElasticTransform(alpha=120, sigma=120 * 0.09, alpha_affine=120 * 0.08, p=0.2),
    A.GaussNoise(var_limit=(0.001, 0.01), p=0.4),
    ToTensorV2(),
])

test_transform = A.Compose([
    ToTensorV2(),
])

def create_dataloader(batch_size=8, threshold=10):
    test_list_path = '/data1/BraTS/test_files.csv'

    df = pd.read_csv(test_list_path)

    test_code_list = []
    for fname in df['filename']:
        test_num = re.search(r'BraTS-MEN-RT-([0-9]{4})', fname).group(1)
        test_code_list.append(test_num)
        
    data_path = '/data1/kerter/BraTS/Preprocessing/train/Normalize'

    base_path = Path(data_path)

    img_path = base_path / 'img'
    mask_path = base_path / 'mask'

    img_list = sorted(img_path.iterdir())
    mask_list = sorted(mask_path.iterdir())

    train_data_list, test_data_list = [], []

    for img_path, mask_path in zip(img_list, mask_list):
        mask = sitk.ReadImage(mask_path)
        mask_data = sitk.GetArrayFromImage(mask)
        
        code = re.search(r'([0-9]{4}).nii.gz', mask_path.name).group(1)
        
        for z, mask_slice in enumerate(mask_data):
            if mask_slice.sum() >= threshold:
                if code in test_code_list:
                    test_data_list.append((z, img_path, mask_path))
                else:
                    train_data_list.append((z, img_path, mask_path))
    
    train_dataset = BraTSDataset(train_data_list, transform=train_transform)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=8)
    
    test_dataset = BraTSDataset(test_data_list, transform=test_transform)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=8)
    
    return train_loader, test_loader

# %%
train_loader, test_loader = create_dataloader(batch_size=16)

# %%
import torch
import torch.nn as nn
import timm

class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class DecoderBlock(nn.Module):
    def __init__(self, in_channels_decoder, in_channels_skip, out_channels, dropout_p=0.2):
        super().__init__()

        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)

        self.conv_block = ConvBlock(in_channels_decoder + in_channels_skip, out_channels)

        self.dropout = nn.Dropout2d(p=dropout_p)

    def forward(self, x_decoder, x_skip):
        x_decoder = self.upsample(x_decoder)

        x = torch.cat([x_decoder, x_skip], dim=1) # dim=1은 채널 차원

        x = self.conv_block(x)

        x = self.dropout(x)
        
        return x

class CustomModel(nn.Module):
    def __init__(self, encoder_name='resnet50', pretrained=True, classes=1, dropout_rate=0.3):
        super().__init__()
        self.encoder = timm.create_model(encoder_name, pretrained=pretrained, features_only=True)
        self.encoder_channels = self.encoder.feature_info.channels()
        
        self.dropout_enc = nn.Dropout2d(p=dropout_rate)
        
        self.decoder5 = DecoderBlock(self.encoder_channels[4], self.encoder_channels[3], 512, dropout_p=dropout_rate) # From Layer4 to Layer3 Skip
        self.decoder4 = DecoderBlock(512, self.encoder_channels[2], 256, dropout_p=dropout_rate) # From Layer3 to Layer2 Skip
        self.decoder3 = DecoderBlock(256, self.encoder_channels[1], 128, dropout_p=dropout_rate) # From Layer2 to Layer1 Skip
        self.decoder2 = DecoderBlock(128, self.encoder_channels[0], 64, dropout_p=dropout_rate) # From Layer1 to Conv1_relu/stem Skip
        
        self.upsample_final = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)
        self.final_conv = nn.Conv2d(64, classes, kernel_size=1)

        self.final_dropout = nn.Dropout2d(p=dropout_rate)

    def forward(self, x):
        encoder_outputs = self.encoder(x)

        x = self.dropout_enc(encoder_outputs[4])

        d5 = self.decoder5(x, encoder_outputs[3])
        d4 = self.decoder4(d5, encoder_outputs[2])
        d3 = self.decoder3(d4, encoder_outputs[1])
        d2 = self.decoder2(d3, encoder_outputs[0])
        
        x = self.upsample_final(d2)

        x = self.final_dropout(x) 
        output = self.final_conv(x)
        
        return output

# %%
# <셀 1>
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import segmentation_models_pytorch as smp

# 기본 설정
DEVICE = 'cuda:1' if torch.cuda.is_available() else 'cpu'
THRESHOLD = 0.5

print(f"사용 장치: {DEVICE}")
# Out:
# 사용 장치: cuda:1

# %%
def train_one_epoch(model, loader, optimizer, scheduler, criterion, device):
    model.train()
    
    total_epoch_loss, total_epoch_iou, total_epoch_dice = 0.0, 0.0, 0.0
    num_batches = len(loader)

    for i, (images, masks) in enumerate(loader):
        images, masks = images.to(device, non_blocking=True), masks.to(device, non_blocking=True)
        
        optimizer.zero_grad()
        logits = model(images)
        loss = criterion(logits, masks)
        loss.backward()
        optimizer.step()
        if scheduler:
            scheduler.step()
        
        with torch.no_grad():
            probs = torch.sigmoid(logits)
            pred_masks = (probs > THRESHOLD).float()
            tp, fp, fn, tn = smp.metrics.get_stats(pred_masks.long(), masks.long(), mode='binary')
            
            iou = smp.metrics.iou_score(tp, fp, fn, tn)
            dice = smp.metrics.f1_score(tp, fp, fn, tn)
        
        total_epoch_loss += loss.item()
        total_epoch_iou += iou.mean().item()
        total_epoch_dice += dice.mean().item()
    
    return total_epoch_loss / num_batches, total_epoch_iou / num_batches, total_epoch_dice / num_batches

# %%
def validate(model, loader, criterion, device):
    model.eval()
    total_loss, total_iou, total_dice = 0.0, 0.0, 0.0
    num_batches = len(loader)
    
    with torch.no_grad():
        for images, masks in loader:
            images, masks = images.to(device, non_blocking=True), masks.to(device, non_blocking=True)

            logits = model(images)
            loss = criterion(logits, masks)
            probs = torch.sigmoid(logits)
            pred_masks = (probs > THRESHOLD).float()
            tp, fp, fn, tn = smp.metrics.get_stats(pred_masks.long(), masks.long(), mode='binary')
            
            iou = smp.metrics.iou_score(tp, fp, fn, tn)
            dice = smp.metrics.f1_score(tp, fp, fn, tn)

            total_loss += loss.item()
            total_iou += iou.mean().item()
            total_dice += dice.mean().item()

    return total_loss / num_batches, total_iou / num_batches, total_dice / num_batches

# %%
best_lr = 0.0085
best_wd = 4e-05
best_do = 0.30

print("--- 최종 학습을 시작합니다 ---")
print(f"사용할 하이퍼파라미터: LR={best_lr:.6f}, WD={best_wd:.6f}, DropOut={best_do:.6f}")

FINAL_EPOCHS = 75
T_0 = 5 

final_model = CustomModel(dropout_rate=best_do).to(DEVICE)

dice_loss = smp.losses.DiceLoss(mode='binary')
bce_loss = smp.losses.SoftBCEWithLogitsLoss()
criterion = lambda logits, masks: dice_loss(logits, masks) + bce_loss(logits, masks)

optimizer = optim.SGD(final_model.parameters(), lr=best_lr, momentum=0.9, weight_decay=best_wd)
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=T_0 * len(train_loader), T_mult=2)

best_iou = 0.0
best_dice = 0.0

history = {
    'train_loss': [],
    'train_iou': [],
    'train_dice': [],
    'val_loss': [],
    'val_iou': [],
    'val_dice': []
}

for epoch in range(1, FINAL_EPOCHS + 1):
    print(f"\n--- 최종 학습 Epoch {epoch}/{FINAL_EPOCHS} ---")
    
    train_loss, train_iou, train_dice = train_one_epoch(final_model, train_loader, optimizer, scheduler, criterion, DEVICE)
    val_loss, val_iou, val_dice = validate(final_model, test_loader, criterion, DEVICE)

    history['train_loss'].append(train_loss)
    history['train_iou'].append(train_iou)
    history['train_dice'].append(train_dice)
    history['val_loss'].append(val_loss)
    history['val_iou'].append(val_iou)
    history['val_dice'].append(val_dice)

    print(f"Train Loss: {train_loss:.4f}, Train IoU: {train_iou:.4f}, Train Dice: {train_dice:.4f}"
          f"\nValid Loss: {val_loss:.4f}, Valid IoU: {val_iou:.4f}, Valid Dice: {val_dice:.4f}")

    if val_dice > best_dice:
        best_iou = val_iou
        best_dice = val_dice 
        torch.save(final_model.state_dict(), 'best_model.pth')
        print(f"  >> 새로운 최고 성능 달성! (IoU: {best_iou:.4f} / Dice: {best_dice:.4f}). 'best_model.pth'에 모델을 저장합니다.")


print("\n--- 최종 학습 완료 ---")

print(f"최고 검증 IoU: {best_iou:.4f}")
print(f"최고 검증 Dice: {best_dice:.4f}")

import matplotlib.pyplot as plt

# 손실 그래프
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# IoU 및 Dice 그래프
plt.subplot(1, 2, 2)
plt.plot(history['train_iou'], label='Train IoU')
plt.plot(history['val_iou'], label='Validation IoU')
plt.plot(history['train_dice'], label='Train Dice')
plt.plot(history['val_dice'], label='Validation Dice')
plt.title('Metrics over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# --- 최종 학습을 시작합니다 ---
# 사용할 하이퍼파라미터: LR=0.008503, WD=0.000043, DropOut=0.129814
#
# --- 최종 학습 Epoch 1/75 ---
# Train Loss: 0.2679, Train IoU: 0.4936, Train Dice: 0.5714
# Valid Loss: 0.3763, Valid IoU: 0.4905, Valid Dice: 0.5544
#   >> 새로운 최고 성능 달성! (IoU: 0.4905 / Dice: 0.5544). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 2/75 ---
# Train Loss: 0.1522, Train IoU: 0.5818, Train Dice: 0.6550
# Valid Loss: 0.2852, Valid IoU: 0.5768, Valid Dice: 0.6448
#   >> 새로운 최고 성능 달성! (IoU: 0.5768 / Dice: 0.6448). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 3/75 ---
# Train Loss: 0.1359, Train IoU: 0.6098, Train Dice: 0.6832
# Valid Loss: 0.2625, Valid IoU: 0.5996, Valid Dice: 0.6678
#   >> 새로운 최고 성능 달성! (IoU: 0.5996 / Dice: 0.6678). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 4/75 ---
# Train Loss: 0.1254, Train IoU: 0.6287, Train Dice: 0.7029
# Valid Loss: 0.2538, Valid IoU: 0.6120, Valid Dice: 0.6822
#   >> 새로운 최고 성능 달성! (IoU: 0.6120 / Dice: 0.6822). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 5/75 ---
# Train Loss: 0.1201, Train IoU: 0.6377, Train Dice: 0.7116
# Valid Loss: 0.2528, Valid IoU: 0.6137, Valid Dice: 0.6841
#   >> 새로운 최고 성능 달성! (IoU: 0.6137 / Dice: 0.6841). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 6/75 ---
# Train Loss: 0.1314, Train IoU: 0.6179, Train Dice: 0.6919
# Valid Loss: 0.2900, Valid IoU: 0.5744, Valid Dice: 0.6411
#
# --- 최종 학습 Epoch 7/75 ---
# Train Loss: 0.1237, Train IoU: 0.6313, Train Dice: 0.7055
# Valid Loss: 0.2552, Valid IoU: 0.6147, Valid Dice: 0.6930
#   >> 새로운 최고 성능 달성! (IoU: 0.6147 / Dice: 0.6930). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 8/75 ---
# Train Loss: 0.1159, Train IoU: 0.6447, Train Dice: 0.7188
# Valid Loss: 0.2725, Valid IoU: 0.5985, Valid Dice: 0.6668
#
# --- 최종 학습 Epoch 9/75 ---
# Train Loss: 0.1132, Train IoU: 0.6538, Train Dice: 0.7281
# Valid Loss: 0.2598, Valid IoU: 0.6125, Valid Dice: 0.6868
#
# --- 최종 학습 Epoch 10/75 ---
# Train Loss: 0.1090, Train IoU: 0.6624, Train Dice: 0.7368
# Valid Loss: 0.2566, Valid IoU: 0.6088, Valid Dice: 0.6774
#
# --- 최종 학습 Epoch 11/75 ---
# Train Loss: 0.1052, Train IoU: 0.6717, Train Dice: 0.7455
# Valid Loss: 0.2478, Valid IoU: 0.6228, Valid Dice: 0.6967
#   >> 새로운 최고 성능 달성! (IoU: 0.6228 / Dice: 0.6967). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 12/75 ---
# Train Loss: 0.1029, Train IoU: 0.6761, Train Dice: 0.7500
# Valid Loss: 0.2510, Valid IoU: 0.6206, Valid Dice: 0.6918
#
# --- 최종 학습 Epoch 13/75 ---
# Train Loss: 0.1006, Train IoU: 0.6811, Train Dice: 0.7550
# Valid Loss: 0.2473, Valid IoU: 0.6223, Valid Dice: 0.6939
#
# --- 최종 학습 Epoch 14/75 ---
# Train Loss: 0.0985, Train IoU: 0.6853, Train Dice: 0.7590
# Valid Loss: 0.2481, Valid IoU: 0.6208, Valid Dice: 0.6931
#
# --- 최종 학습 Epoch 15/75 ---
# Train Loss: 0.0984, Train IoU: 0.6847, Train Dice: 0.7580
# Valid Loss: 0.2492, Valid IoU: 0.6185, Valid Dice: 0.6897
#
# --- 최종 학습 Epoch 16/75 ---
# Train Loss: 0.1075, Train IoU: 0.6660, Train Dice: 0.7399
# Valid Loss: 0.2489, Valid IoU: 0.6201, Valid Dice: 0.6927
#
# --- 최종 학습 Epoch 17/75 ---
# Train Loss: 0.1061, Train IoU: 0.6692, Train Dice: 0.7438
# Valid Loss: 0.2468, Valid IoU: 0.6188, Valid Dice: 0.6896
#
# --- 최종 학습 Epoch 18/75 ---
# Train Loss: 0.1025, Train IoU: 0.6753, Train Dice: 0.7497
# Valid Loss: 0.2836, Valid IoU: 0.5837, Valid Dice: 0.6503
#
# --- 최종 학습 Epoch 19/75 ---
# Train Loss: 0.1021, Train IoU: 0.6788, Train Dice: 0.7534
# Valid Loss: 0.2413, Valid IoU: 0.6319, Valid Dice: 0.7062
#   >> 새로운 최고 성능 달성! (IoU: 0.6319 / Dice: 0.7062). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 20/75 ---
# Train Loss: 0.0990, Train IoU: 0.6837, Train Dice: 0.7578
# Valid Loss: 0.2793, Valid IoU: 0.5930, Valid Dice: 0.6614
#
# --- 최종 학습 Epoch 21/75 ---
# Train Loss: 0.0973, Train IoU: 0.6889, Train Dice: 0.7633
# Valid Loss: 0.2761, Valid IoU: 0.5904, Valid Dice: 0.6552
#
# --- 최종 학습 Epoch 22/75 ---
# Train Loss: 0.0936, Train IoU: 0.6964, Train Dice: 0.7706
# Valid Loss: 0.2757, Valid IoU: 0.5979, Valid Dice: 0.6673
#
# --- 최종 학습 Epoch 23/75 ---
# Train Loss: 0.0916, Train IoU: 0.7001, Train Dice: 0.7744
# Valid Loss: 0.2456, Valid IoU: 0.6228, Valid Dice: 0.6949
#
# --- 최종 학습 Epoch 24/75 ---
# Train Loss: 0.0904, Train IoU: 0.7031, Train Dice: 0.7768
# Valid Loss: 0.2481, Valid IoU: 0.6209, Valid Dice: 0.6936
#
# --- 최종 학습 Epoch 25/75 ---
# Train Loss: 0.0892, Train IoU: 0.7074, Train Dice: 0.7810
# Valid Loss: 0.2520, Valid IoU: 0.6169, Valid Dice: 0.6921
#
# --- 최종 학습 Epoch 26/75 ---
# Train Loss: 0.0878, Train IoU: 0.7106, Train Dice: 0.7840
# Valid Loss: 0.2337, Valid IoU: 0.6379, Valid Dice: 0.7142
#   >> 새로운 최고 성능 달성! (IoU: 0.6379 / Dice: 0.7142). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 27/75 ---
# Train Loss: 0.0862, Train IoU: 0.7141, Train Dice: 0.7873
# Valid Loss: 0.2346, Valid IoU: 0.6364, Valid Dice: 0.7138
#
# --- 최종 학습 Epoch 28/75 ---
# Train Loss: 0.0848, Train IoU: 0.7185, Train Dice: 0.7915
# Valid Loss: 0.2255, Valid IoU: 0.6419, Valid Dice: 0.7203
#   >> 새로운 최고 성능 달성! (IoU: 0.6419 / Dice: 0.7203). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 29/75 ---
# Train Loss: 0.0838, Train IoU: 0.7199, Train Dice: 0.7928
# Valid Loss: 0.2398, Valid IoU: 0.6271, Valid Dice: 0.7018
#
# --- 최종 학습 Epoch 30/75 ---
# Train Loss: 0.0828, Train IoU: 0.7232, Train Dice: 0.7963
# Valid Loss: 0.2329, Valid IoU: 0.6384, Valid Dice: 0.7169
#
# --- 최종 학습 Epoch 31/75 ---
# Train Loss: 0.0821, Train IoU: 0.7245, Train Dice: 0.7971
# Valid Loss: 0.2315, Valid IoU: 0.6378, Valid Dice: 0.7141
#
# --- 최종 학습 Epoch 32/75 ---
# Train Loss: 0.0812, Train IoU: 0.7285, Train Dice: 0.8012
# Valid Loss: 0.2299, Valid IoU: 0.6378, Valid Dice: 0.7139
#
# --- 최종 학습 Epoch 33/75 ---
# Train Loss: 0.0809, Train IoU: 0.7282, Train Dice: 0.8008
# Valid Loss: 0.2276, Valid IoU: 0.6404, Valid Dice: 0.7180
#
# --- 최종 학습 Epoch 34/75 ---
# Train Loss: 0.0804, Train IoU: 0.7298, Train Dice: 0.8027
# Valid Loss: 0.2290, Valid IoU: 0.6401, Valid Dice: 0.7169
#
# --- 최종 학습 Epoch 35/75 ---
# Train Loss: 0.0811, Train IoU: 0.7287, Train Dice: 0.8015
# Valid Loss: 0.2290, Valid IoU: 0.6396, Valid Dice: 0.7169
#
# --- 최종 학습 Epoch 36/75 ---
# Train Loss: 0.0888, Train IoU: 0.7094, Train Dice: 0.7836
# Valid Loss: 0.2510, Valid IoU: 0.6141, Valid Dice: 0.6897
#
# --- 최종 학습 Epoch 37/75 ---
# Train Loss: 0.0887, Train IoU: 0.7087, Train Dice: 0.7827
# Valid Loss: 0.2540, Valid IoU: 0.6147, Valid Dice: 0.6898
#
# --- 최종 학습 Epoch 38/75 ---
# Train Loss: 0.0886, Train IoU: 0.7094, Train Dice: 0.7834
# Valid Loss: 0.2855, Valid IoU: 0.5847, Valid Dice: 0.6554
#
# --- 최종 학습 Epoch 39/75 ---
# Train Loss: 0.0864, Train IoU: 0.7152, Train Dice: 0.7891
# Valid Loss: 0.2353, Valid IoU: 0.6324, Valid Dice: 0.7086
#
# --- 최종 학습 Epoch 40/75 ---
# Train Loss: 0.0851, Train IoU: 0.7193, Train Dice: 0.7928
# Valid Loss: 0.2266, Valid IoU: 0.6442, Valid Dice: 0.7213
#   >> 새로운 최고 성능 달성! (IoU: 0.6442 / Dice: 0.7213). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 41/75 ---
# Train Loss: 0.0840, Train IoU: 0.7215, Train Dice: 0.7955
# Valid Loss: 0.2393, Valid IoU: 0.6307, Valid Dice: 0.7066
#
# --- 최종 학습 Epoch 42/75 ---
# Train Loss: 0.0830, Train IoU: 0.7235, Train Dice: 0.7969
# Valid Loss: 0.2726, Valid IoU: 0.5967, Valid Dice: 0.6689
#
# --- 최종 학습 Epoch 43/75 ---
# Train Loss: 0.0819, Train IoU: 0.7256, Train Dice: 0.7986
# Valid Loss: 0.2521, Valid IoU: 0.6185, Valid Dice: 0.6930
#
# --- 최종 학습 Epoch 44/75 ---
# Train Loss: 0.0815, Train IoU: 0.7284, Train Dice: 0.8014
# Valid Loss: 0.2569, Valid IoU: 0.6089, Valid Dice: 0.6824
#
# --- 최종 학습 Epoch 45/75 ---
# Train Loss: 0.0805, Train IoU: 0.7303, Train Dice: 0.8030
# Valid Loss: 0.2383, Valid IoU: 0.6354, Valid Dice: 0.7123
#
# --- 최종 학습 Epoch 46/75 ---
# Train Loss: 0.0786, Train IoU: 0.7335, Train Dice: 0.8065
# Valid Loss: 0.2319, Valid IoU: 0.6394, Valid Dice: 0.7176
#
# --- 최종 학습 Epoch 47/75 ---
# Train Loss: 0.0787, Train IoU: 0.7360, Train Dice: 0.8089
# Valid Loss: 0.2294, Valid IoU: 0.6437, Valid Dice: 0.7230
#   >> 새로운 최고 성능 달성! (IoU: 0.6437 / Dice: 0.7230). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 48/75 ---
# Train Loss: 0.0775, Train IoU: 0.7376, Train Dice: 0.8096
# Valid Loss: 0.2478, Valid IoU: 0.6215, Valid Dice: 0.6957
#
# --- 최종 학습 Epoch 49/75 ---
# Train Loss: 0.0770, Train IoU: 0.7390, Train Dice: 0.8111
# Valid Loss: 0.2311, Valid IoU: 0.6401, Valid Dice: 0.7175
#
# --- 최종 학습 Epoch 50/75 ---
# Train Loss: 0.0764, Train IoU: 0.7433, Train Dice: 0.8156
# Valid Loss: 0.2213, Valid IoU: 0.6543, Valid Dice: 0.7352
#   >> 새로운 최고 성능 달성! (IoU: 0.6543 / Dice: 0.7352). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 51/75 ---
# Train Loss: 0.0761, Train IoU: 0.7439, Train Dice: 0.8162
# Valid Loss: 0.2476, Valid IoU: 0.6261, Valid Dice: 0.7010
#
# --- 최종 학습 Epoch 52/75 ---
# Train Loss: 0.0755, Train IoU: 0.7468, Train Dice: 0.8181
# Valid Loss: 0.2187, Valid IoU: 0.6626, Valid Dice: 0.7476
#   >> 새로운 최고 성능 달성! (IoU: 0.6626 / Dice: 0.7476). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 53/75 ---
# Train Loss: 0.0742, Train IoU: 0.7495, Train Dice: 0.8212
# Valid Loss: 0.2254, Valid IoU: 0.6483, Valid Dice: 0.7279
#
# --- 최종 학습 Epoch 54/75 ---
# Train Loss: 0.0736, Train IoU: 0.7514, Train Dice: 0.8232
# Valid Loss: 0.2294, Valid IoU: 0.6410, Valid Dice: 0.7187
#
# --- 최종 학습 Epoch 55/75 ---
# Train Loss: 0.0734, Train IoU: 0.7504, Train Dice: 0.8218
# Valid Loss: 0.2383, Valid IoU: 0.6410, Valid Dice: 0.7237
#
# --- 최종 학습 Epoch 56/75 ---
# Train Loss: 0.0726, Train IoU: 0.7532, Train Dice: 0.8242
# Valid Loss: 0.2409, Valid IoU: 0.6326, Valid Dice: 0.7146
#
# --- 최종 학습 Epoch 57/75 ---
# Train Loss: 0.0718, Train IoU: 0.7544, Train Dice: 0.8252
# Valid Loss: 0.2384, Valid IoU: 0.6354, Valid Dice: 0.7164
#
# --- 최종 학습 Epoch 58/75 ---
# Train Loss: 0.0712, Train IoU: 0.7578, Train Dice: 0.8284
# Valid Loss: 0.2371, Valid IoU: 0.6350, Valid Dice: 0.7138
#
# --- 최종 학습 Epoch 59/75 ---
# Train Loss: 0.0704, Train IoU: 0.7590, Train Dice: 0.8294
# Valid Loss: 0.2291, Valid IoU: 0.6434, Valid Dice: 0.7239
#
# --- 최종 학습 Epoch 60/75 ---
# Train Loss: 0.0703, Train IoU: 0.7611, Train Dice: 0.8314
# Valid Loss: 0.2432, Valid IoU: 0.6286, Valid Dice: 0.7070
#
# --- 최종 학습 Epoch 61/75 ---
# Train Loss: 0.0694, Train IoU: 0.7614, Train Dice: 0.8319
# Valid Loss: 0.2422, Valid IoU: 0.6323, Valid Dice: 0.7111
#
# --- 최종 학습 Epoch 62/75 ---
# Train Loss: 0.0694, Train IoU: 0.7633, Train Dice: 0.8334
# Valid Loss: 0.2365, Valid IoU: 0.6337, Valid Dice: 0.7131
#
# --- 최종 학습 Epoch 63/75 ---
# Train Loss: 0.0686, Train IoU: 0.7647, Train Dice: 0.8346
# Valid Loss: 0.2441, Valid IoU: 0.6247, Valid Dice: 0.7030
#
# --- 최종 학습 Epoch 64/75 ---
# Train Loss: 0.0687, Train IoU: 0.7656, Train Dice: 0.8357
# Valid Loss: 0.2299, Valid IoU: 0.6415, Valid Dice: 0.7223
#
# --- 최종 학습 Epoch 65/75 ---
# Train Loss: 0.0678, Train IoU: 0.7673, Train Dice: 0.8374
# Valid Loss: 0.2343, Valid IoU: 0.6379, Valid Dice: 0.7176
#
# --- 최종 학습 Epoch 66/75 ---
# Train Loss: 0.0683, Train IoU: 0.7659, Train Dice: 0.8358
# Valid Loss: 0.2369, Valid IoU: 0.6367, Valid Dice: 0.7157
#
# --- 최종 학습 Epoch 67/75 ---
# Train Loss: 0.0670, Train IoU: 0.7676, Train Dice: 0.8367
# Valid Loss: 0.2359, Valid IoU: 0.6361, Valid Dice: 0.7155
#
# --- 최종 학습 Epoch 68/75 ---
# Train Loss: 0.0672, Train IoU: 0.7710, Train Dice: 0.8406
# Valid Loss: 0.2397, Valid IoU: 0.6336, Valid Dice: 0.7131
#
# --- 최종 학습 Epoch 69/75 ---
# Train Loss: 0.0675, Train IoU: 0.7696, Train Dice: 0.8395
# Valid Loss: 0.2360, Valid IoU: 0.6377, Valid Dice: 0.7186
#
# --- 최종 학습 Epoch 70/75 ---
# Train Loss: 0.0669, Train IoU: 0.7703, Train Dice: 0.8399
# Valid Loss: 0.2364, Valid IoU: 0.6373, Valid Dice: 0.7180
#
# --- 최종 학습 Epoch 71/75 ---
# Train Loss: 0.0666, Train IoU: 0.7709, Train Dice: 0.8404
# Valid Loss: 0.2387, Valid IoU: 0.6350, Valid Dice: 0.7148
#
# --- 최종 학습 Epoch 72/75 ---
# Train Loss: 0.0667, Train IoU: 0.7708, Train Dice: 0.8400
# Valid Loss: 0.2375, Valid IoU: 0.6359, Valid Dice: 0.7160
#
# --- 최종 학습 Epoch 73/75 ---
# Train Loss: 0.0668, Train IoU: 0.7697, Train Dice: 0.8391
# Valid Loss: 0.2383, Valid IoU: 0.6357, Valid Dice: 0.7165
#
# --- 최종 학습 Epoch 74/75 ---
# Train Loss: 0.0665, Train IoU: 0.7711, Train Dice: 0.8406
# Valid Loss: 0.2369, Valid IoU: 0.6369, Valid Dice: 0.7172
#
# --- 최종 학습 Epoch 75/75 ---
# Train Loss: 0.0668, Train IoU: 0.7721, Train Dice: 0.8416
# Valid Loss: 0.2367, Valid IoU: 0.6369, Valid Dice: 0.7168
#
# --- 최종 학습 완료 ---
# 최고 검증 IoU: 0.6626
# 최고 검증 Dice: 0.7476
