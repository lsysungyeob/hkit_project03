# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import re
from pathlib import Path
import SimpleITK as sitk
import numpy as np
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
def normalize(img):
    max_value = img.max()
    min_value = img.min()
    
    return (img - min_value) / (max_value - min_value + 1e-8)

def image_pad_crop(img, mask, size, margin=1):
    if img.ndim == 3 and img.shape[2] == 1:
        non_black_flat = img[:,:,0] > 0
    elif img.ndim == 2:
        non_black_flat = img > 0
    else:
        non_black_flat = np.sum(img, axis=-1) > 0 if img.ndim == 3 else np.sum(img, axis=0) > 0 
        
    coords = np.argwhere(non_black_flat)

    if len(coords) == 0:
        if img.ndim == 3:
            h, w, _ = img.shape
        else: 
            h, w = img.shape
        center_y, center_x = h // 2, w // 2
    else:
        y_min, x_min = coords.min(axis=0)
        y_max, x_max = coords.max(axis=0)

        if img.ndim == 3:
            h, w, _ = img.shape
        else:
            h, w = img.shape
            
        y_min = max(0, y_min - margin)
        x_min = max(0, x_min - margin)
        y_max = min(h - 1, y_max + margin)
        x_max = min(w - 1, x_max + margin)
        
        center_y = (y_min + y_max) // 2
        center_x = (x_min + x_max) // 2

    half_size = size // 2
    crop_start_y = center_y - half_size
    crop_end_y = center_y + half_size
    crop_start_x = center_x - half_size
    crop_end_x = center_x + half_size

    if img.ndim == 3: 
        img_result = np.zeros((size, size, img.shape[2]), dtype=img.dtype)
    else: 
        img_result = np.zeros((size, size), dtype=img.dtype)
        
    mask_result = np.zeros((size, size), dtype=mask.dtype)

    src_start_y = max(0, crop_start_y)
    src_end_y = min(h, crop_end_y) 
    src_start_x = max(0, crop_start_x)
    src_end_x = min(w, crop_end_x) 
    
    dest_start_y = max(0, -crop_start_y)
    dest_end_y = dest_start_y + (src_end_y - src_start_y)
    dest_start_x = max(0, -crop_start_x)
    dest_end_x = dest_start_x + (src_end_x - src_start_x)

    img_result[dest_start_y:dest_end_y, dest_start_x:dest_end_x] = img[src_start_y:src_end_y, src_start_x:src_end_x]
    mask_result[dest_start_y:dest_end_y, dest_start_x:dest_end_x] = mask[src_start_y:src_end_y, src_start_x:src_end_x]
    
    return img_result, mask_result

class BraTSDataset(Dataset):
    def __init__(self, data_list, transform=None, out_size=256):
        self.data_list = data_list
        self.transform = transform
        self.out_size = out_size
        
    def __len__(self):
        return len(self.data_list)
    
    def __getitem__(self, idx):
        z_current, img_path, mask_path = self.data_list[idx]
        
        full_image_volume = sitk.GetArrayFromImage(sitk.ReadImage(img_path))
        full_mask_volume = sitk.GetArrayFromImage(sitk.ReadImage(mask_path))

        total_slices = full_image_volume.shape[0]

        z_prev = max(0, z_current - 1)
        z_next = min(total_slices - 1, z_current + 1)

        image_prev = full_image_volume[z_prev]
        image_current = full_image_volume[z_current]
        image_next = full_image_volume[z_next]
        
        mask_data = full_mask_volume[z_current]

        image_prev_norm = normalize(image_prev)
        image_current_norm = normalize(image_current)
        image_next_norm = normalize(image_next)

        combined_image_3channel = np.stack([image_prev_norm, image_current_norm, image_next_norm], axis=-1) 

        image_new, mask_new = image_pad_crop(combined_image_3channel, mask_data, self.out_size)
        
        make_t = self.transform(image=image_new, mask=mask_new)
        image_tensor = make_t['image']
        mask_tensor = make_t['mask']
        
        return image_tensor.float(), mask_tensor.float().unsqueeze(0)

# %%
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=10, p=0.7),
    A.ShiftScaleRotate(shift_limit=0.02, scale_limit=0.05, rotate_limit=0, p=0.7),
    A.ElasticTransform(alpha=120, sigma=120 * 0.09, alpha_affine=120 * 0.08, p=0.2),
    A.GaussNoise(var_limit=(0.001, 0.01), p=0.4),
    ToTensorV2(),
])

test_transform = A.Compose([
    ToTensorV2(),
])

def create_dataloader(batch_size=8, threshold=10):
    test_list_path = '/data1/BraTS/test_files.csv'

    df = pd.read_csv(test_list_path)

    test_code_list = []
    for fname in df['filename']:
        test_num = re.search(r'BraTS-MEN-RT-([0-9]{4})', fname).group(1)
        test_code_list.append(test_num)
        
    data_path = '/data1/kerter/BraTS/Preprocessing/train/Normalize'

    base_path = Path(data_path)

    img_path = base_path / 'img'
    mask_path = base_path / 'mask'

    img_list = sorted(img_path.iterdir())
    mask_list = sorted(mask_path.iterdir())

    train_data_list, test_data_list = [], []

    for img_path, mask_path in zip(img_list, mask_list):
        mask = sitk.ReadImage(mask_path)
        mask_data = sitk.GetArrayFromImage(mask)
        
        code = re.search(r'([0-9]{4}).nii.gz', mask_path.name).group(1)
        
        for z, mask_slice in enumerate(mask_data):
            if mask_slice.sum() >= threshold:
                if code in test_code_list:
                    test_data_list.append((z, img_path, mask_path))
                else:
                    train_data_list.append((z, img_path, mask_path))
    
    train_dataset = BraTSDataset(train_data_list, transform=train_transform)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=8)
    
    test_dataset = BraTSDataset(test_data_list, transform=test_transform)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=8)
    
    return train_loader, test_loader

# %%
train_loader, test_loader = create_dataloader(batch_size=16)

# %%
import torch
import torch.nn as nn
import timm

class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class DecoderBlock(nn.Module):
    def __init__(self, in_channels_decoder, in_channels_skip, out_channels, dropout_p=0.2):
        super().__init__()

        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)

        self.conv_block = ConvBlock(in_channels_decoder + in_channels_skip, out_channels)

        self.dropout = nn.Dropout2d(p=dropout_p)

    def forward(self, x_decoder, x_skip):
        x_decoder = self.upsample(x_decoder)

        x = torch.cat([x_decoder, x_skip], dim=1) # dim=1은 채널 차원

        x = self.conv_block(x)

        x = self.dropout(x)
        
        return x

class CustomModel(nn.Module):
    def __init__(self, encoder_name='resnet50', pretrained=True, classes=1, dropout_rate=0.3):
        super().__init__()
        self.encoder = timm.create_model(encoder_name, pretrained=pretrained, features_only=True)
        self.encoder_channels = self.encoder.feature_info.channels()
        
        self.dropout_enc = nn.Dropout2d(p=dropout_rate)
        
        self.decoder5 = DecoderBlock(self.encoder_channels[4], self.encoder_channels[3], 512, dropout_p=dropout_rate) # From Layer4 to Layer3 Skip
        self.decoder4 = DecoderBlock(512, self.encoder_channels[2], 256, dropout_p=dropout_rate) # From Layer3 to Layer2 Skip
        self.decoder3 = DecoderBlock(256, self.encoder_channels[1], 128, dropout_p=dropout_rate) # From Layer2 to Layer1 Skip
        self.decoder2 = DecoderBlock(128, self.encoder_channels[0], 64, dropout_p=dropout_rate) # From Layer1 to Conv1_relu/stem Skip
        
        self.upsample_final = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=False)
        self.final_conv = nn.Conv2d(64, classes, kernel_size=1)

        self.final_dropout = nn.Dropout2d(p=dropout_rate)

    def forward(self, x):
        encoder_outputs = self.encoder(x)

        x = self.dropout_enc(encoder_outputs[4])

        d5 = self.decoder5(x, encoder_outputs[3])
        d4 = self.decoder4(d5, encoder_outputs[2])
        d3 = self.decoder3(d4, encoder_outputs[1])
        d2 = self.decoder2(d3, encoder_outputs[0])
        
        x = self.upsample_final(d2)

        x = self.final_dropout(x)
        output = self.final_conv(x)
        
        return output

# %%
# <셀 1>
import torch
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import segmentation_models_pytorch as smp

# 기본 설정
DEVICE = 'cuda:1' if torch.cuda.is_available() else 'cpu'
THRESHOLD = 0.5

print(f"사용 장치: {DEVICE}")
# Out:
# 사용 장치: cuda:1

# %%
def train_one_epoch(model, loader, optimizer, scheduler, criterion, device):
    model.train()
    
    total_epoch_loss, total_epoch_iou, total_epoch_dice = 0.0, 0.0, 0.0
    num_batches = len(loader)

    for i, (images, masks) in enumerate(loader):
        images, masks = images.to(device, non_blocking=True), masks.to(device, non_blocking=True)
        
        optimizer.zero_grad()
        logits = model(images)
        loss = criterion(logits, masks)
        loss.backward()
        optimizer.step()
        if scheduler:
            scheduler.step()
        
        with torch.no_grad():
            probs = torch.sigmoid(logits)
            pred_masks = (probs > THRESHOLD).float()
            tp, fp, fn, tn = smp.metrics.get_stats(pred_masks.long(), masks.long(), mode='binary')
            
            iou = smp.metrics.iou_score(tp, fp, fn, tn)
            dice = smp.metrics.f1_score(tp, fp, fn, tn)
        
        total_epoch_loss += loss.item()
        total_epoch_iou += iou.mean().item()
        total_epoch_dice += dice.mean().item()
    
    return total_epoch_loss / num_batches, total_epoch_iou / num_batches, total_epoch_dice / num_batches

# %%
def validate(model, loader, criterion, device):
    model.eval()
    
    total_loss, total_iou, total_dice = 0.0, 0.0, 0.0
    num_batches = len(loader)
    
    with torch.no_grad():
        for images, masks in loader:
            images, masks = images.to(device, non_blocking=True), masks.to(device, non_blocking=True)

            logits = model(images)
            loss = criterion(logits, masks)
            probs = torch.sigmoid(logits)
            pred_masks = (probs > THRESHOLD).float()
            tp, fp, fn, tn = smp.metrics.get_stats(pred_masks.long(), masks.long(), mode='binary')
            
            iou = smp.metrics.iou_score(tp, fp, fn, tn)
            dice = smp.metrics.f1_score(tp, fp, fn, tn)

            total_loss += loss.item()
            total_iou += iou.mean().item()
            total_dice += dice.mean().item()

    return total_loss / num_batches, total_iou / num_batches, total_dice / num_batches

# %%
best_lr = 1.66e-03
best_wd = 7e-05

print("--- 3단계: 최종 학습을 시작합니다 ---")
print(f"사용할 하이퍼파라미터: LR={best_lr:.6f}, WD={best_wd:.6f}")

FINAL_EPOCHS = 75

T_0 = 5

final_model = CustomModel(dropout_rate=0.5).to(DEVICE)

dice_loss = smp.losses.DiceLoss(mode='binary')
bce_loss = smp.losses.SoftBCEWithLogitsLoss()
criterion = lambda logits, masks: dice_loss(logits, masks) + bce_loss(logits, masks)

optimizer = optim.AdamW(final_model.parameters(), lr=best_lr, weight_decay=best_wd)
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=T_0 * len(train_loader), T_mult=2)

best_iou = 0.0
best_dice = 0.0

history = {
    'train_loss': [],
    'train_iou': [],
    'train_dice': [],
    'val_loss': [],
    'val_iou': [],
    'val_dice': []
}

for epoch in range(1, FINAL_EPOCHS + 1):
    print(f"\n--- 최종 학습 Epoch {epoch}/{FINAL_EPOCHS} ---")
    
    train_loss, train_iou, train_dice = train_one_epoch(final_model, train_loader, optimizer, scheduler, criterion, DEVICE)
    val_loss, val_iou, val_dice = validate(final_model, test_loader, criterion, DEVICE)

    history['train_loss'].append(train_loss)
    history['train_iou'].append(train_iou)
    history['train_dice'].append(train_dice)
    history['val_loss'].append(val_loss)
    history['val_iou'].append(val_iou)
    history['val_dice'].append(val_dice)

    print(f"Train Loss: {train_loss:.4f}, Train IoU: {train_iou:.4f}, Train Dice: {train_dice:.4f}"
          f"\nValid Loss: {val_loss:.4f}, Valid IoU: {val_iou:.4f}, Valid Dice: {val_dice:.4f}")

    if val_dice > best_dice:
        best_iou = val_iou
        best_dice = val_dice 
        torch.save(final_model.state_dict(), 'best_model.pth')
        print(f"  >> 새로운 최고 성능 달성! (IoU: {best_iou:.4f} / Dice: {best_dice:.4f}). 'best_model.pth'에 모델을 저장합니다.")


print("\n--- 최종 학습 완료 ---")

print(f"최고 검증 IoU: {best_iou:.4f}")
print(f"최고 검증 Dice: {best_dice:.4f}")

import matplotlib.pyplot as plt

# 손실 그래프
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# IoU 및 Dice 그래프
plt.subplot(1, 2, 2)
plt.plot(history['train_iou'], label='Train IoU')
plt.plot(history['val_iou'], label='Validation IoU')
plt.plot(history['train_dice'], label='Train Dice')
plt.plot(history['val_dice'], label='Validation Dice')
plt.title('Metrics over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# --- 3단계: 최종 학습을 시작합니다 ---
# 사용할 하이퍼파라미터: LR=0.001660, WD=0.000070
#
# --- 최종 학습 Epoch 1/75 ---
# Train Loss: 0.4563, Train IoU: 0.4587, Train Dice: 0.5347
# Valid Loss: 0.3996, Valid IoU: 0.4686, Valid Dice: 0.5253
#   >> 새로운 최고 성능 달성! (IoU: 0.4686 / Dice: 0.5253). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 2/75 ---
# Train Loss: 0.1911, Train IoU: 0.5501, Train Dice: 0.6225
# Valid Loss: 0.3845, Valid IoU: 0.4850, Valid Dice: 0.5404
#   >> 새로운 최고 성능 달성! (IoU: 0.4850 / Dice: 0.5404). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 3/75 ---
# Train Loss: 0.1587, Train IoU: 0.5790, Train Dice: 0.6498
# Valid Loss: 0.3195, Valid IoU: 0.5427, Valid Dice: 0.6082
#   >> 새로운 최고 성능 달성! (IoU: 0.5427 / Dice: 0.6082). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 4/75 ---
# Train Loss: 0.1450, Train IoU: 0.6023, Train Dice: 0.6741
# Valid Loss: 0.2880, Valid IoU: 0.5640, Valid Dice: 0.6266
#   >> 새로운 최고 성능 달성! (IoU: 0.5640 / Dice: 0.6266). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 5/75 ---
# Train Loss: 0.1340, Train IoU: 0.6187, Train Dice: 0.6914
# Valid Loss: 0.2636, Valid IoU: 0.5902, Valid Dice: 0.6594
#   >> 새로운 최고 성능 달성! (IoU: 0.5902 / Dice: 0.6594). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 6/75 ---
# Train Loss: 0.1773, Train IoU: 0.5634, Train Dice: 0.6355
# Valid Loss: 0.3318, Valid IoU: 0.5221, Valid Dice: 0.5829
#
# --- 최종 학습 Epoch 7/75 ---
# Train Loss: 0.1573, Train IoU: 0.5816, Train Dice: 0.6521
# Valid Loss: 0.2914, Valid IoU: 0.5604, Valid Dice: 0.6237
#
# --- 최종 학습 Epoch 8/75 ---
# Train Loss: 0.1431, Train IoU: 0.6017, Train Dice: 0.6734
# Valid Loss: 0.2670, Valid IoU: 0.5875, Valid Dice: 0.6531
#
# --- 최종 학습 Epoch 9/75 ---
# Train Loss: 0.1351, Train IoU: 0.6190, Train Dice: 0.6917
# Valid Loss: 0.2821, Valid IoU: 0.5743, Valid Dice: 0.6406
#
# --- 최종 학습 Epoch 10/75 ---
# Train Loss: 0.1333, Train IoU: 0.6210, Train Dice: 0.6933
# Valid Loss: 0.2686, Valid IoU: 0.5989, Valid Dice: 0.6723
#   >> 새로운 최고 성능 달성! (IoU: 0.5989 / Dice: 0.6723). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 11/75 ---
# Train Loss: 0.1247, Train IoU: 0.6364, Train Dice: 0.7100
# Valid Loss: 0.2385, Valid IoU: 0.6190, Valid Dice: 0.6899
#   >> 새로운 최고 성능 달성! (IoU: 0.6190 / Dice: 0.6899). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 12/75 ---
# Train Loss: 0.1195, Train IoU: 0.6450, Train Dice: 0.7186
# Valid Loss: 0.2422, Valid IoU: 0.6188, Valid Dice: 0.6878
#
# --- 최종 학습 Epoch 13/75 ---
# Train Loss: 0.1156, Train IoU: 0.6542, Train Dice: 0.7288
# Valid Loss: 0.2384, Valid IoU: 0.6238, Valid Dice: 0.6962
#   >> 새로운 최고 성능 달성! (IoU: 0.6238 / Dice: 0.6962). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 14/75 ---
# Train Loss: 0.1138, Train IoU: 0.6625, Train Dice: 0.7372
# Valid Loss: 0.2422, Valid IoU: 0.6207, Valid Dice: 0.6913
#
# --- 최종 학습 Epoch 15/75 ---
# Train Loss: 0.1125, Train IoU: 0.6625, Train Dice: 0.7375
# Valid Loss: 0.2382, Valid IoU: 0.6249, Valid Dice: 0.6968
#   >> 새로운 최고 성능 달성! (IoU: 0.6249 / Dice: 0.6968). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 16/75 ---
# Train Loss: 0.1471, Train IoU: 0.6010, Train Dice: 0.6735
# Valid Loss: 0.2888, Valid IoU: 0.5748, Valid Dice: 0.6434
#
# --- 최종 학습 Epoch 17/75 ---
# Train Loss: 0.1357, Train IoU: 0.6253, Train Dice: 0.6996
# Valid Loss: 0.2888, Valid IoU: 0.5722, Valid Dice: 0.6369
#
# --- 최종 학습 Epoch 18/75 ---
# Train Loss: 0.1335, Train IoU: 0.6335, Train Dice: 0.7087
# Valid Loss: 0.2735, Valid IoU: 0.5873, Valid Dice: 0.6557
#
# --- 최종 학습 Epoch 19/75 ---
# Train Loss: 0.1246, Train IoU: 0.6462, Train Dice: 0.7219
# Valid Loss: 0.2516, Valid IoU: 0.6073, Valid Dice: 0.6766
#
# --- 최종 학습 Epoch 20/75 ---
# Train Loss: 0.1218, Train IoU: 0.6534, Train Dice: 0.7291
# Valid Loss: 0.2504, Valid IoU: 0.6138, Valid Dice: 0.6839
#
# --- 최종 학습 Epoch 21/75 ---
# Train Loss: 0.1156, Train IoU: 0.6620, Train Dice: 0.7376
# Valid Loss: 0.2670, Valid IoU: 0.6026, Valid Dice: 0.6705
#
# --- 최종 학습 Epoch 22/75 ---
# Train Loss: 0.1148, Train IoU: 0.6639, Train Dice: 0.7403
# Valid Loss: 0.2568, Valid IoU: 0.6126, Valid Dice: 0.6806
#
# --- 최종 학습 Epoch 23/75 ---
# Train Loss: 0.1143, Train IoU: 0.6676, Train Dice: 0.7432
# Valid Loss: 0.2523, Valid IoU: 0.6145, Valid Dice: 0.6833
#
# --- 최종 학습 Epoch 24/75 ---
# Train Loss: 0.1082, Train IoU: 0.6789, Train Dice: 0.7558
# Valid Loss: 0.2585, Valid IoU: 0.6109, Valid Dice: 0.6784
#
# --- 최종 학습 Epoch 25/75 ---
# Train Loss: 0.1083, Train IoU: 0.6780, Train Dice: 0.7545
# Valid Loss: 0.2588, Valid IoU: 0.6093, Valid Dice: 0.6789
#
# --- 최종 학습 Epoch 26/75 ---
# Train Loss: 0.1031, Train IoU: 0.6888, Train Dice: 0.7658
# Valid Loss: 0.2463, Valid IoU: 0.6250, Valid Dice: 0.6963
#
# --- 최종 학습 Epoch 27/75 ---
# Train Loss: 0.1018, Train IoU: 0.6947, Train Dice: 0.7720
# Valid Loss: 0.2395, Valid IoU: 0.6260, Valid Dice: 0.6963
#
# --- 최종 학습 Epoch 28/75 ---
# Train Loss: 0.1007, Train IoU: 0.7000, Train Dice: 0.7777
# Valid Loss: 0.2472, Valid IoU: 0.6259, Valid Dice: 0.7001
#   >> 새로운 최고 성능 달성! (IoU: 0.6259 / Dice: 0.7001). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 29/75 ---
# Train Loss: 0.0976, Train IoU: 0.7030, Train Dice: 0.7798
# Valid Loss: 0.2401, Valid IoU: 0.6299, Valid Dice: 0.7020
#   >> 새로운 최고 성능 달성! (IoU: 0.6299 / Dice: 0.7020). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 30/75 ---
# Train Loss: 0.0959, Train IoU: 0.7063, Train Dice: 0.7829
# Valid Loss: 0.2360, Valid IoU: 0.6349, Valid Dice: 0.7073
#   >> 새로운 최고 성능 달성! (IoU: 0.6349 / Dice: 0.7073). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 31/75 ---
# Train Loss: 0.0947, Train IoU: 0.7097, Train Dice: 0.7860
# Valid Loss: 0.2403, Valid IoU: 0.6322, Valid Dice: 0.7022
#
# --- 최종 학습 Epoch 32/75 ---
# Train Loss: 0.0941, Train IoU: 0.7113, Train Dice: 0.7881
# Valid Loss: 0.2433, Valid IoU: 0.6289, Valid Dice: 0.6992
#
# --- 최종 학습 Epoch 33/75 ---
# Train Loss: 0.0926, Train IoU: 0.7137, Train Dice: 0.7900
# Valid Loss: 0.2420, Valid IoU: 0.6304, Valid Dice: 0.7011
#
# --- 최종 학습 Epoch 34/75 ---
# Train Loss: 0.0927, Train IoU: 0.7144, Train Dice: 0.7909
# Valid Loss: 0.2426, Valid IoU: 0.6306, Valid Dice: 0.7021
#
# --- 최종 학습 Epoch 35/75 ---
# Train Loss: 0.0926, Train IoU: 0.7157, Train Dice: 0.7925
# Valid Loss: 0.2415, Valid IoU: 0.6315, Valid Dice: 0.7031
#
# --- 최종 학습 Epoch 36/75 ---
# Train Loss: 0.1195, Train IoU: 0.6623, Train Dice: 0.7386
# Valid Loss: 0.2686, Valid IoU: 0.6116, Valid Dice: 0.6815
#
# --- 최종 학습 Epoch 37/75 ---
# Train Loss: 0.1091, Train IoU: 0.6790, Train Dice: 0.7561
# Valid Loss: 0.2745, Valid IoU: 0.5995, Valid Dice: 0.6662
#
# --- 최종 학습 Epoch 38/75 ---
# Train Loss: 0.1096, Train IoU: 0.6809, Train Dice: 0.7584
# Valid Loss: 0.2523, Valid IoU: 0.6129, Valid Dice: 0.6817
#
# --- 최종 학습 Epoch 39/75 ---
# Train Loss: 0.1038, Train IoU: 0.6898, Train Dice: 0.7674
# Valid Loss: 0.2405, Valid IoU: 0.6289, Valid Dice: 0.6974
#
# --- 최종 학습 Epoch 40/75 ---
# Train Loss: 0.1064, Train IoU: 0.6868, Train Dice: 0.7643
# Valid Loss: 0.2648, Valid IoU: 0.6071, Valid Dice: 0.6771
#
# --- 최종 학습 Epoch 41/75 ---
# Train Loss: 0.1062, Train IoU: 0.6825, Train Dice: 0.7595
# Valid Loss: 0.2582, Valid IoU: 0.6112, Valid Dice: 0.6773
#
# --- 최종 학습 Epoch 42/75 ---
# Train Loss: 0.1019, Train IoU: 0.6961, Train Dice: 0.7739
# Valid Loss: 0.2453, Valid IoU: 0.6240, Valid Dice: 0.6955
#
# --- 최종 학습 Epoch 43/75 ---
# Train Loss: 0.0994, Train IoU: 0.6985, Train Dice: 0.7756
# Valid Loss: 0.2544, Valid IoU: 0.6267, Valid Dice: 0.7017
#
# --- 최종 학습 Epoch 44/75 ---
# Train Loss: 0.0990, Train IoU: 0.6994, Train Dice: 0.7761
# Valid Loss: 0.2633, Valid IoU: 0.6100, Valid Dice: 0.6786
#
# --- 최종 학습 Epoch 45/75 ---
# Train Loss: 0.0966, Train IoU: 0.7043, Train Dice: 0.7813
# Valid Loss: 0.2619, Valid IoU: 0.6105, Valid Dice: 0.6802
#
# --- 최종 학습 Epoch 46/75 ---
# Train Loss: 0.0980, Train IoU: 0.7030, Train Dice: 0.7803
# Valid Loss: 0.2730, Valid IoU: 0.6068, Valid Dice: 0.6797
#
# --- 최종 학습 Epoch 47/75 ---
# Train Loss: 0.0969, Train IoU: 0.7065, Train Dice: 0.7835
# Valid Loss: 0.2553, Valid IoU: 0.6155, Valid Dice: 0.6845
#
# --- 최종 학습 Epoch 48/75 ---
# Train Loss: 0.0935, Train IoU: 0.7130, Train Dice: 0.7898
# Valid Loss: 0.2645, Valid IoU: 0.6147, Valid Dice: 0.6883
#
# --- 최종 학습 Epoch 49/75 ---
# Train Loss: 0.0928, Train IoU: 0.7151, Train Dice: 0.7918
# Valid Loss: 0.2387, Valid IoU: 0.6314, Valid Dice: 0.7032
#
# --- 최종 학습 Epoch 50/75 ---
# Train Loss: 0.0923, Train IoU: 0.7129, Train Dice: 0.7890
# Valid Loss: 0.2719, Valid IoU: 0.6101, Valid Dice: 0.6820
#
# --- 최종 학습 Epoch 51/75 ---
# Train Loss: 0.0909, Train IoU: 0.7181, Train Dice: 0.7945
# Valid Loss: 0.2602, Valid IoU: 0.6180, Valid Dice: 0.6915
#
# --- 최종 학습 Epoch 52/75 ---
# Train Loss: 0.0896, Train IoU: 0.7204, Train Dice: 0.7966
# Valid Loss: 0.2760, Valid IoU: 0.6054, Valid Dice: 0.6779
#
# --- 최종 학습 Epoch 53/75 ---
# Train Loss: 0.0923, Train IoU: 0.7167, Train Dice: 0.7936
# Valid Loss: 0.2614, Valid IoU: 0.6151, Valid Dice: 0.6868
#
# --- 최종 학습 Epoch 54/75 ---
# Train Loss: 0.0887, Train IoU: 0.7213, Train Dice: 0.7974
# Valid Loss: 0.2441, Valid IoU: 0.6318, Valid Dice: 0.7036
#
# --- 최종 학습 Epoch 55/75 ---
# Train Loss: 0.0858, Train IoU: 0.7313, Train Dice: 0.8077
# Valid Loss: 0.2441, Valid IoU: 0.6304, Valid Dice: 0.7050
#
# --- 최종 학습 Epoch 56/75 ---
# Train Loss: 0.0853, Train IoU: 0.7320, Train Dice: 0.8082
# Valid Loss: 0.2359, Valid IoU: 0.6398, Valid Dice: 0.7147
#   >> 새로운 최고 성능 달성! (IoU: 0.6398 / Dice: 0.7147). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 57/75 ---
# Train Loss: 0.0848, Train IoU: 0.7349, Train Dice: 0.8112
# Valid Loss: 0.2393, Valid IoU: 0.6374, Valid Dice: 0.7131
#
# --- 최종 학습 Epoch 58/75 ---
# Train Loss: 0.0841, Train IoU: 0.7386, Train Dice: 0.8146
# Valid Loss: 0.2450, Valid IoU: 0.6343, Valid Dice: 0.7092
#
# --- 최종 학습 Epoch 59/75 ---
# Train Loss: 0.0821, Train IoU: 0.7396, Train Dice: 0.8150
# Valid Loss: 0.2445, Valid IoU: 0.6287, Valid Dice: 0.7003
#
# --- 최종 학습 Epoch 60/75 ---
# Train Loss: 0.0819, Train IoU: 0.7403, Train Dice: 0.8160
# Valid Loss: 0.2459, Valid IoU: 0.6310, Valid Dice: 0.7060
#
# --- 최종 학습 Epoch 61/75 ---
# Train Loss: 0.0799, Train IoU: 0.7422, Train Dice: 0.8172
# Valid Loss: 0.2368, Valid IoU: 0.6379, Valid Dice: 0.7107
#
# --- 최종 학습 Epoch 62/75 ---
# Train Loss: 0.0813, Train IoU: 0.7450, Train Dice: 0.8200
# Valid Loss: 0.2333, Valid IoU: 0.6438, Valid Dice: 0.7188
#   >> 새로운 최고 성능 달성! (IoU: 0.6438 / Dice: 0.7188). 'best_model.pth'에 모델을 저장합니다.
#
# --- 최종 학습 Epoch 63/75 ---
# Train Loss: 0.0792, Train IoU: 0.7479, Train Dice: 0.8229
# Valid Loss: 0.2399, Valid IoU: 0.6380, Valid Dice: 0.7115
#
# --- 최종 학습 Epoch 64/75 ---
# Train Loss: 0.0796, Train IoU: 0.7514, Train Dice: 0.8268
# Valid Loss: 0.2406, Valid IoU: 0.6381, Valid Dice: 0.7127
#
# --- 최종 학습 Epoch 65/75 ---
# Train Loss: 0.0777, Train IoU: 0.7518, Train Dice: 0.8266
# Valid Loss: 0.2387, Valid IoU: 0.6389, Valid Dice: 0.7150
#
# --- 최종 학습 Epoch 66/75 ---
# Train Loss: 0.0771, Train IoU: 0.7529, Train Dice: 0.8273
# Valid Loss: 0.2362, Valid IoU: 0.6404, Valid Dice: 0.7152
#
# --- 최종 학습 Epoch 67/75 ---
# Train Loss: 0.0761, Train IoU: 0.7536, Train Dice: 0.8281
# Valid Loss: 0.2430, Valid IoU: 0.6336, Valid Dice: 0.7082
#
# --- 최종 학습 Epoch 68/75 ---
# Train Loss: 0.0760, Train IoU: 0.7565, Train Dice: 0.8310
# Valid Loss: 0.2394, Valid IoU: 0.6361, Valid Dice: 0.7114
#
# --- 최종 학습 Epoch 69/75 ---
# Train Loss: 0.0765, Train IoU: 0.7559, Train Dice: 0.8300
# Valid Loss: 0.2442, Valid IoU: 0.6336, Valid Dice: 0.7084
#
# --- 최종 학습 Epoch 70/75 ---
# Train Loss: 0.0756, Train IoU: 0.7569, Train Dice: 0.8309
# Valid Loss: 0.2421, Valid IoU: 0.6351, Valid Dice: 0.7101
#
# --- 최종 학습 Epoch 71/75 ---
# Train Loss: 0.0758, Train IoU: 0.7564, Train Dice: 0.8305
# Valid Loss: 0.2448, Valid IoU: 0.6325, Valid Dice: 0.7068
#
# --- 최종 학습 Epoch 72/75 ---
# Train Loss: 0.0752, Train IoU: 0.7577, Train Dice: 0.8318
# Valid Loss: 0.2419, Valid IoU: 0.6359, Valid Dice: 0.7109
#
# --- 최종 학습 Epoch 73/75 ---
# Train Loss: 0.0750, Train IoU: 0.7587, Train Dice: 0.8329
# Valid Loss: 0.2414, Valid IoU: 0.6369, Valid Dice: 0.7124
#
# --- 최종 학습 Epoch 74/75 ---
# Train Loss: 0.0752, Train IoU: 0.7596, Train Dice: 0.8339
# Valid Loss: 0.2408, Valid IoU: 0.6370, Valid Dice: 0.7120
#
# --- 최종 학습 Epoch 75/75 ---
# Train Loss: 0.0750, Train IoU: 0.7594, Train Dice: 0.8337
# Valid Loss: 0.2415, Valid IoU: 0.6365, Valid Dice: 0.7115
#
# --- 최종 학습 완료 ---
# 최고 검증 IoU: 0.6438
# 최고 검증 Dice: 0.7188
